# %% [markdown]
# <a href="https://colab.research.google.com/github/weso500/IOT-Anomaly-Detection/blob/main/Second_Level_AUC_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/AUC Generation Second Level Normaltrain.csv')
print(df.head)
# Out:
# <bound method NDFrame.head of      A+_IGBT-IMSE   A+IGBT-IMSE     A-FLUXMSE    B+_FLUXMSE    B+_IGBTMSE  \
# 0    3.773371e-14  3.926026e-14  4.575507e-14  4.314604e-14  4.378442e-14
# 1    3.497203e-14  3.760880e-14  4.637957e-14  3.966272e-14  4.343748e-14
# 2    3.660267e-14  3.647777e-14  4.423545e-14  4.057171e-14  4.100192e-14
# 3    3.939904e-14  3.923251e-14  4.488077e-14  4.347911e-14  4.134193e-14
# 4    3.763656e-14  3.733125e-14  4.370115e-14  3.841372e-14  3.833045e-14
# ..            ...           ...           ...           ...           ...
# 195  5.311029e-14  5.100087e-14  5.505318e-14  5.860590e-14  5.502543e-14
# 196  4.585091e-14  4.564621e-14  4.229820e-14  4.935505e-14  4.584918e-14
# 197  5.820518e-14  5.627269e-14  6.115768e-14  6.837413e-14  6.443283e-14
# 198  4.626594e-14  4.200893e-14  3.938256e-14  4.693208e-14  4.214424e-14
# 199  5.238344e-14  5.088464e-14  5.496471e-14  5.607494e-14  5.483634e-14
#
#       B+IGBT-IMSE  C+_IGBT-IMSE   C+IGBT-IMSE       CB-IMSE       CB-VMSE  \
# 0    4.361789e-14  4.031497e-14  4.264644e-14  3.953782e-14  3.270995e-14
# 1    4.152234e-14  3.533285e-14  3.827494e-14  3.866352e-14  2.539635e-14
# 2    4.040518e-14  3.718553e-14  3.713002e-14  3.435446e-14  2.727679e-14
# 3    3.939904e-14  3.756717e-14  3.959333e-14  3.938516e-14  2.760292e-14
# 4    3.959333e-14  3.552714e-14  3.474998e-14  3.427814e-14  2.380041e-14
# ..            ...           ...           ...           ...           ...
# 195  5.519196e-14  5.608014e-14  5.530298e-14  4.664324e-14  5.698220e-14
# 196  4.006040e-14  3.687892e-14  4.480834e-14  4.220626e-14  4.111338e-14
# 197  6.375629e-14  6.013072e-14  5.988092e-14  6.015848e-14  5.891815e-14
# 198  4.154056e-14  3.665037e-14  4.558593e-14  3.780743e-14  3.917006e-14
# 199  5.571411e-14  5.446511e-14  5.543656e-14  4.541680e-14  5.405398e-14
#
#         C-FLUXMSE      DV_DTMSE      MOD-IMSE      MOD-VMSE  Target
# 0    4.572731e-14  3.690104e-14  3.914924e-14  5.158374e-14       0
# 1    4.332645e-14  3.376466e-14  3.505529e-14  5.009881e-14       0
# 2    4.046069e-14  3.270995e-14  3.782391e-14  5.118822e-14       0
# 3    4.002354e-14  3.370915e-14  3.716472e-14  5.041800e-14       0
# 4    3.989864e-14  3.307077e-14  3.591571e-14  4.876655e-14       0
# ..            ...           ...           ...           ...     ...
# 195  4.989065e-14  4.451994e-14  5.608014e-14  5.299927e-14       1
# 196  4.298688e-14  4.099368e-14  3.916529e-14  5.077709e-14       1
# 197  5.020810e-14  5.550942e-14  6.354466e-14  6.111604e-14       1
# 198  4.146770e-14  3.624271e-14  3.963236e-14  4.802669e-14       1
# 199  4.844215e-14  4.365432e-14  5.560309e-14  5.350755e-14       1
#
# [200 rows x 15 columns]>

# %%
from sklearn import metrics
from matplotlib import pyplot as plt
fpr, tpr, thresholds = metrics.roc_curve(df['Target'], df['A+_IGBT-IMSE'] , pos_label=1)
print(thresholds)
fpr1, tpr1, thresholds1 = metrics.roc_curve(df['Target'], df['A+IGBT-IMSE'] , pos_label=1)
print(thresholds1)
fpr2, tpr2, thresholds2 = metrics.roc_curve(df['Target'], df['A-FLUXMSE'] , pos_label=1)
print(thresholds2)
fpr3, tpr3, thresholds3 = metrics.roc_curve(df['Target'], df['B+_FLUXMSE'] , pos_label=1)
print(thresholds3)
fpr4, tpr4, thresholds4 = metrics.roc_curve(df['Target'], df['B+_IGBTMSE'] , pos_label=1)
fpr5, tpr5, thresholds5 = metrics.roc_curve(df['Target'], df['B+IGBT-IMSE'] , pos_label=1)
fpr6, tpr6, thresholds6 = metrics.roc_curve(df['Target'], df['C+_IGBT-IMSE'] , pos_label=1)
fpr7, tpr7, thresholds7 = metrics.roc_curve(df['Target'], df['C+IGBT-IMSE'] , pos_label=1)
fpr8, tpr8, thresholds8 = metrics.roc_curve(df['Target'], df['CB-IMSE'] , pos_label=1)
fpr9, tpr9, thresholds9 = metrics.roc_curve(df['Target'], df['CB-VMSE'] , pos_label=1)
fpr10, tpr10, thresholds10 = metrics.roc_curve(df['Target'], df['C-FLUXMSE'] , pos_label=1)
fpr11, tpr11, thresholds11 = metrics.roc_curve(df['Target'], df['DV_DTMSE'] , pos_label=1)
fpr12, tpr12, thresholds12 = metrics.roc_curve(df['Target'], df['MOD-IMSE'] , pos_label=1)
fpr13, tpr13, thresholds13 = metrics.roc_curve(df['Target'], df['MOD-VMSE'] , pos_label=1)
#pyplot.plot(fpr, tpr, marker='.', label='Logistic')
auc = metrics.auc(fpr, tpr)
auc1 = metrics.auc(fpr1, tpr1)
auc2 = metrics.auc(fpr2, tpr2)
auc3 = metrics.auc(fpr3, tpr3)
auc4 = metrics.auc(fpr4, tpr4)
auc5 = metrics.auc(fpr5, tpr5)
auc6 = metrics.auc(fpr6, tpr6)
auc7 = metrics.auc(fpr7, tpr7)
auc8 = metrics.auc(fpr8, tpr8)
auc9 = metrics.auc(fpr9, tpr9)
auc10 = metrics.auc(fpr10, tpr10)
auc11 = metrics.auc(fpr11, tpr11)
auc12 = metrics.auc(fpr12, tpr12)
auc13 = metrics.auc(fpr13, tpr13)
print(auc)

#plt.figure(0).clf()
#fpr, tpr, _ = metrics.roc_curve(y_test, prediction_loss)
#auc = round(metrics.roc_auc_score(y_test, prediction_loss), 4)
plt.plot(fpr,tpr,marker='.',label="A+*IGBT="+str(auc))
plt.plot(fpr1,tpr1,marker='.',label="A+IGBT="+str(auc1))
plt.plot(fpr2,tpr2,marker='.',label="A-FLUX="+str(auc2))
plt.plot(fpr3,tpr3,marker='.',label="B+FLUX="+str(round(auc3, 2)))
plt.plot(fpr4,tpr4,marker='.',label="B+*IGBT="+str(auc4))
plt.plot(fpr5,tpr5,marker='.',label="B+IGBT="+str(auc5))
plt.plot(fpr6,tpr6,marker='.',label="C+*IGBT="+str(auc6))
plt.plot(fpr7,tpr7,marker='.',label="C+IGBT="+str(auc7))
plt.plot(fpr8,tpr8,marker='.',label="CB-I="+str(auc8))
plt.plot(fpr9,tpr9,marker='.',label="CB-V="+str(round(auc9, 2)))
plt.plot(fpr10,tpr10,marker='.',label="C-FLUX="+str(auc10))
plt.plot(fpr11,tpr11,marker='.',label="DV_DT="+str(round(auc11, 2)))
plt.plot(fpr12,tpr12,marker='.',label="MOD-I="+str(auc12))
plt.plot(fpr13,tpr13,marker='.',label="MOD-V="+str(auc13))
#plt.legend(loc='lower right', prop={'size': 5.8})
# Place legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=8.5)

# Adjust the position of the plot to make room for the legend
# This setting moves the plot leftwards, reducing its width
#plt.set_position([0.1, 0.1, 0.6, 0.8])  # [left, bottom, width, height]
plt.show()
# Out:
# [           inf 6.09512441e-14 4.62659425e-14 4.59077221e-14
#  4.58509099e-14 4.17998969e-14 4.17556614e-14 4.05994682e-14
#  4.04676292e-14 4.04398737e-14 4.03566069e-14 3.98778233e-14
#  3.98570066e-14 3.84241250e-14 3.84137167e-14 3.79002385e-14
#  3.78586051e-14 3.76643161e-14 3.76365605e-14 3.72479825e-14
#  3.72202269e-14 3.69287934e-14 3.69149156e-14 3.68975683e-14
#  3.68871600e-14 3.64708264e-14 3.64430708e-14 3.63598041e-14
#  3.62765373e-14 3.60822483e-14 3.60267371e-14 3.56104035e-14
#  3.55548924e-14 3.53909610e-14 3.52495810e-14 3.50136586e-14
#  3.49720253e-14 3.42850748e-14 3.41393580e-14 3.32511796e-14]
# [           inf 5.85035492e-14 4.66883476e-14 4.64350780e-14
#  4.56462125e-14 4.32709424e-14 4.31156846e-14 4.20219415e-14
#  4.20089311e-14 3.98986399e-14 3.98847622e-14 3.97737399e-14
#  3.97182287e-14 3.96627176e-14 3.96072064e-14 3.91423005e-14
#  3.90659727e-14 3.89792365e-14 3.89688282e-14 3.87884169e-14
#  3.87745391e-14 3.83781548e-14 3.83304499e-14 3.82818777e-14
#  3.82749388e-14 3.82333054e-14 3.82194276e-14 3.80528942e-14
#  3.80251386e-14 3.79973830e-14 3.78308496e-14 3.78100329e-14
#  3.77198273e-14 3.76920717e-14 3.76226827e-14 3.76088050e-14
#  3.74153833e-14 3.74145159e-14 3.64777653e-14 3.64708264e-14
#  3.38479245e-14]
# [           inf 6.89448498e-14 5.49647133e-14 4.99617708e-14
#  4.98108499e-14 4.80171458e-14 4.79893902e-14 4.71983563e-14
#  4.69346784e-14 4.68722283e-14 4.68236561e-14 4.64628336e-14
#  4.64073224e-14 4.58452720e-14 4.57550664e-14 4.56232274e-14
#  4.56024107e-14 4.53456717e-14 4.53387328e-14 4.52741143e-14
#  4.52693438e-14 4.48807658e-14 4.48391324e-14 4.45286169e-14
#  4.45199433e-14 4.43677213e-14 4.43256543e-14 4.42285097e-14
#  4.42146320e-14 4.41729986e-14 4.41591208e-14 4.40758541e-14
#  4.40480985e-14 4.33472702e-14 4.33403313e-14 4.31599201e-14
#  4.31460423e-14 4.30003255e-14 4.29795088e-14 4.24833779e-14
#  4.22981962e-14 4.22283736e-14 4.19152560e-14 3.94684285e-14
#  3.93825597e-14]
# [           inf 6.87505608e-14 4.93550513e-14 4.69901895e-14
#  4.69320763e-14 4.60759902e-14 4.59909888e-14 4.52944973e-14
#  4.52424556e-14 4.49085213e-14 4.48530102e-14 4.36456427e-14
#  4.35901315e-14 4.28684865e-14 4.28268532e-14 4.24417446e-14
#  4.23966418e-14 4.18276525e-14 4.17443857e-14 4.16888746e-14
#  4.14390744e-14 4.14113188e-14 4.11198853e-14 4.11060075e-14
#  4.08492684e-14 4.08006962e-14 4.02317069e-14 4.02178291e-14
#  3.97112898e-14 3.96904731e-14 3.84137167e-14]
# 0.9963157894736842
